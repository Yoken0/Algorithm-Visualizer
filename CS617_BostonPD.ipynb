# %% [markdown]
# <a href="https://colab.research.google.com/github/Yoken0/Algorithm-Visualizer/blob/main/CS617_BostonPD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
sql = '''
SELECT "DISTRICT",
       "OCCURRED_ON_DATE",
       "SHOOTING",
       "OFFENSE_DESCRIPTION"
FROM "b973d8cb-eeb2-4e7e-99da-c92938efc9c0"
WHERE CAST("SHOOTING" AS INT)=1
    '''

# %%
bpd_logs = "https://data.boston.gov/api/3/action/datastore_search_sql"

# %%
import urllib, requests

# %%
url = bpd_logs+"?sql="+urllib.parse.quote(sql)
rows = requests.get( url ).json()

shootings = rows['result']['records']

# %%
print(shootings)
# Out:
# [{'DISTRICT': 'B3', 'OCCURRED_ON_DATE': '2023-02-18 21:43:00+00', 'SHOOTING': '1', 'OFFENSE_DESCRIPTION': 'MURDER, NON-NEGLIGENT MANSLAUGHTER'}, {'DISTRICT': 'D4', 'OCCURRED_ON_DATE': '2023-05-24 18:49:00+00', 'SHOOTING': '1', 'OFFENSE_DESCRIPTION': 'BALLISTICS EVIDENCE/FOUND'}, {'DISTRICT': 'D4', 'OCCURRED_ON_DATE': '2023-10-27 12:50:00+00', 'SHOOTING': '1', 'OFFENSE_DESCRIPTION': 'ASSAULT - AGGRAVATED'}, {'DISTRICT': 'B3', 'OCCURRED_ON_DATE': '2023-01-07 17:51:00+00', 'SHOOTING': '1', 'OFFENSE_DESCRIPTION': 'INVESTIGATE PROPERTY'}, {'DISTRICT': 'B2', 'OCCURRED_ON_DATE': '2023-01-30 17:00:00+00', 'SHOOTING': '1', 'OFFENSE_DESCRIPTION': 'ASSAULT - AGGRAVATED'}, {'DISTRICT': 'C11', 'OCCURRED_ON_DATE': '2023-10-28 20:56:00+00', 'SHOOTING': '1', 'OFFENSE_DESCRIPTION': 'BALLISTICS EVIDENCE/FOUND'}, {'DISTRICT': 'B2', 'OCCURRED_ON_DATE': '2023-10-11 19:21:00+00', 'SHOOTING': '1', 'OFFENSE_DESCRIPTION': 'INVESTIGATE PROPERTY'}, {'DISTRICT': 'B2', 'OCCURRED_ON_DATE': '2023-12-16 16:29:00+00', 'SHOOTING': '1', 'OFFENSE_DESCRIPTION': 'ASSAULT - AGGRAVATED'}, {'DISTRICT': 'D14', 'OCCURRED_ON_DATE': '2025-09-22 22:21:00+00', 'SHOOTING': '1', 'OFFENSE_DESCRIPTION': 'INVESTIGATE PERSON'}, {'DISTRICT': 'E18', 'OCCURRED_ON_DATE': '2024-05-15 17:07:00+00', 'SHOOTING': '1', 'OFFENSE_DESCRIPTION': 'ASSAULT - AGGRAVATED'}, {'DISTRICT': 'C11', 'OCCURRED_ON_DATE': '2024-08-12 18:40:00+00', 'SHOOTING': '1', 'OFFENSE_DESCRIPTION': 'MURDER, NON-NEGLIGENT MANSLAUGHTER'}, {'DISTRICT': 'C11', 'OCCURRED_ON_DATE': '2023-04-14 19:58:00+00', 'SHOOTING': '1', 'OFFENSE_DESCRIPTION': 'BALLISTICS EVIDENCE/FOUND'}, {'DISTRICT': 'B2', 'OCCURRED_ON_DATE': '2025-12-08 19:21:00+00', 'SHOOTING': '1', 'OFFENSE_DESCRIPTION': 'INVESTIGATE PROPERTY'}, {'DISTRICT': 'B3', 'OCCURRED_ON_DATE': '2024-07-10 21:47:00+00', 'SHOOTING': '1', 'OFFENSE_DESCRIPTION': 'ASSAULT - AGGRAVATED'}, {'DISTRICT': 'A1', 'OCCURRED_ON_DATE': '2024-05-14 21:45:00+00', 'SHOOTING': '1', 'OFFENSE_DESCRIPTION': 'INVESTIGATE PROPERTY'}, {'DISTRICT': 'C11', 'OCCURRED_ON_DATE': '2023-05-04 00:21:00+00', 'SHOOTING': '1', 'OFFENSE_DESCRIPTION': 'BALLISTICS EVIDENCE/FOUND'}, {'DISTRICT': 'B2', 'OCCURRED_ON_DATE': '2024-05-22 17:06:00+00', 'SHOOTING': '1', 'OFFENSE_DESCRIPTION': 'ASSAULT - AGGRAVATED'}, {'DISTRICT': 'B2', 'OCCURRED_ON_DATE': '2024-05-18 03:42:00+00', 'SHOOTING': '1', 'OFFENSE_DESCRIPTION': 'BALLISTICS EVIDENCE/FOUND'}, {'DISTRICT': 'E13', 'OCCURRED_ON_DATE': '2024-12-27 19:20:00+00', 'SHOOTING': '1', 'OFFENSE_DESCRIPTION': 'WEAPON VIOLATION - CARRY/ POSSESSING/ SALE/ TRAFFICKING/ OTHER'}, {'DISTRICT': 'B2', 'OCCURRED_ON_DATE': '2025-08-06 20:29:00+00', 'SHOOTING': '1', 'OFFENSE_DESCRIPTION': 'INVESTIGATE PROPERTY'}, {'DISTRICT': 'B3', 'OCCURRED_ON_DATE': '2025-06-12 23:46:00+00', 'SHOOTING': '1', 'OFFENSE_DESCRIPTION': 'ROBBERY'}, {'DISTRICT': 'B2', 'OCCURRED_ON_DATE': '2024-07-02 22:05:00+00', 'SHOOTING': '1', 'OFFENSE_DESCRIPTION': 'ASSAULT - AGGRAVATED'}, {'DISTRICT': 'B3', 'OCCURRED_ON_DATE': '2023-06-11 22:31:00+00', 'SHOOTING': '1', 'OFFENSE_DESCRIPTION': 'VANDALISM'}, {'DISTRICT': 'B2', 'OCCURRED_ON_DATE': '2024-05-18 04:02:00+00', 'SHOOTING': '1', 'OFFENSE_DESCRIPTION': 'ASSAULT - AGGRAVATED'}, {'DISTRICT': 'B3', 'OCCURRED_ON_DATE': '2025-07-24 23:36:00+00', 'SHOOTING': '1', 'OFFENSE_DESCRIPTION': 'WEAPON VIOLATION - CARRY/ POSSESSING/ SALE/ TRAFFICKING/ OTHER'}, {'DISTRICT': 'B2', 'OCCURRED_ON_DATE': '2025-07-17 17:23:00+00', 'SHOOTING': '1', 'OFFENSE_DESCRIPTION': 'ASSAULT - AGGRAVATED'}, {'DISTRICT': 'B2', 'OCCURRED_ON_DATE': '2023-03-18 00:00:00+00', 'SHOOTING': '1', 'OFFENSE_DESCRIPTION': 'INVESTIGATE PROPERTY'}, {'DISTRICT': 'B2', 'OCCURRED_ON_DATE': '2024-11-17 00:14:00+00', 'SHOOTING': '1', 'OFFENSE_DESCRIPTION': 'ASSAULT - AGGRAVATED'}, {'DISTRICT': 'B3', 'OCCURRED_ON_DATE': '2023-04-12 00:57:00+00', 'SHOOTING': '1', 'OFFENSE_DESCRIPTION': 'INVESTIGATE PROPERTY'}, {'DISTRICT': 'C11', 'OCCURRED_ON_DATE': '2024-06-28 20:34:00+00', 'SHOOTING': '1', 'OFFENSE_DESCRIPTION': 'MURD ...
